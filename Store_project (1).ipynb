# %% [markdown]
# ## Online Retail Store Data Analytics ##

# %%
import pandas as pd
import numpy as np

df=pd.read_csv(r"C:\Users\bhati\Downloads\archive (9)\online_retail_II.csv")
# Out:
# C:\Users\bhati\AppData\Local\Temp\ipykernel_19320\2318887531.py:4: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"C:\Users\bhati\Downloads\archive (9)\online_retail_II.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007913 entries, 0 to 1007912
# Data columns (total 13 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1007913 non-null  object
#  1   StockCode    1007913 non-null  object
#  2   Description  1007913 non-null  object
#  3   Quantity     1007913 non-null  int64
#  4   InvoiceDate  1007913 non-null  object
#  5   Price        1007913 non-null  float64
#  6   Customer ID  779425 non-null   float64
#  7   Country      1007913 non-null  object
#  8   Revenue      1007913 non-null  float64
#  9   Year         1007913 non-null  int64
#  10  Month        1007913 non-null  int64
#  11  DayofWeek    1007913 non-null  object
#  12  Hour         1007913 non-null  int64
# dtypes: float64(3), int64(4), object(6)
# memory usage: 100.0+ MB

# %%
df.describe()
# Out:
#            Quantity         Price    Customer ID       Revenue          Year  \
# count  1.007913e+06  1.007913e+06  779425.000000  1.007913e+06  1.007913e+06
# mean   1.111718e+01  4.074252e+00   15320.360461  2.031550e+01  2.010437e+03
# std    1.284700e+02  5.043045e+01    1695.692775  2.057158e+02  5.764132e-01
# min    1.000000e+00  1.000000e-03   12346.000000  1.000000e-03  2.009000e+03
# 25%    1.000000e+00  1.250000e+00   13971.000000  4.130000e+00  2.010000e+03
# 50%    4.000000e+00  2.100000e+00   15247.000000  1.008000e+01  2.010000e+03
# 75%    1.200000e+01  4.130000e+00   16794.000000  1.770000e+01  2.011000e+03
# max    8.099500e+04  2.511109e+04   18287.000000  1.684696e+05  2.011000e+03
#
#               Month          Hour
# count  1.007913e+06  1.007913e+06
# mean   7.403545e+00  1.302004e+01
# std    3.499747e+00  2.433195e+00
# min    1.000000e+00  6.000000e+00
# 25%    4.000000e+00  1.100000e+01
# 50%    8.000000e+00  1.300000e+01
# ...

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country  Revenue  Year  \
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom     83.4  2009
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom     81.0  2009
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom     81.0  2009
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom    100.8  2009
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom     30.0  2009
#
#    Month DayofWeek  Hour
# 0     12   Tuesday     7
# 1     12   Tuesday     7
# 2     12   Tuesday     7
# ...

# %%
df.dtypes
# Out:
# Invoice         object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# Price          float64
# Customer ID    float64
# Country         object
# Revenue        float64
# Year             int64
# Month            int64
# DayofWeek       object
# Hour             int64
# dtype: object

# %% [markdown]
# # DATA CLEANING #

# %%
df=df[~df['Invoice'].astype(str).str.startswith('C')]
df=df[df['Quantity']>0]
df=df[df['Price']>0]
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1007908  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1007909  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1007910  581587     22730           ALARM CLOCK BAKELIKE IVORY         4
# 1007911  581587     22367      CHILDRENS APRON SPACEBOY DESIGN         8
# 1007912  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  Revenue  \
# ...

# %%
df['Revenue'] = df['Quantity'] * df['Price']
df_customers=df.dropna(subset=['Customer ID'])         #made a new df where customer id Nan is dropped
df_customers
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1007908  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1007909  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1007910  581587     22730           ALARM CLOCK BAKELIKE IVORY         4
# 1007911  581587     22367      CHILDRENS APRON SPACEBOY DESIGN         8
# 1007912  581587      POST                              POSTAGE         1
#
#                  InvoiceDate  Price  Customer ID         Country  Revenue  \
# ...

# %% [markdown]
# % of Missing data

# %%
df['Customer ID'].isnull().sum()
missing_percent=(df['Customer ID'].isnull().sum()/ len(df))*100
missing_percent
# Out:
# 22.669416904038346

# %%
df_withoutcid=df[df['Customer ID'].isnull()]
df_withoutcid
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 535      489525    85226C            BLUE PULL BACK RACING CAR         1
# 536      489525     85227          SET/6 3D KIT CARDS FOR KIDS         1
# 981      489548     20804            GLASS CHICKEN BUTTER DISH         1
# 982      489548     22150             3 STRIPEY MICE FELTCRAFT         2
# 983      489548     22142         CHRISTMAS CRAFT WHITE FAIRY          2
# ...         ...       ...                                  ...       ...
# 1007550  581498    85049a        TRADITIONAL CHRISTMAS RIBBONS         5
# 1007551  581498     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS         1
# 1007552  581498     85038      6 CHOCOLATE LOVE HEART T-LIGHTS         1
# 1007553  581498    84997d      CHILDRENS CUTLERY POLKADOT PINK         1
# 1007554  581498    85049e            SCANDINAVIAN REDS RIBBONS         4
#
#                  InvoiceDate  Price  Customer ID         Country  Revenue  \
# ...

# %% [markdown]
# Comparing the customer dataset with and without customer ID

# %%
#  REVENUE SHARE Percentage of Anonymous Customers 

(df_withoutcid['Revenue'].sum()/df['Revenue'].sum())*100
# Out:
# 15.146594701099009

# %%
df_customers['Customer ID'].astype('int')
# Out:
# 0          13085
# 1          13085
# 2          13085
# 3          13085
# 4          13085
#            ...
# 1007908    12680
# 1007909    12680
# 1007910    12680
# 1007911    12680
# 1007912    12680
# Name: Customer ID, Length: 779425, dtype: int32

# %%
df_customers['Revenue'].mean()
# Out:
# 22.291823161946304

# %%
df_withoutcid['Revenue'].mean()
# Out:
# 13.573825233710304

# %% [markdown]
# ### Cleaning Date & Time ###

# %%
df['InvoiceDate']=pd.to_datetime(df['InvoiceDate'],errors='coerce')

# %%
df['InvoiceDate'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['Year']=df['InvoiceDate'].dt.year
df['Month']=df['InvoiceDate'].dt.month
df['DayofWeek']=df['InvoiceDate'].dt.day_name()
df['Hour']=df['InvoiceDate'].dt.hour

# %%
df = df.drop_duplicates()
df
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 0        489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1        489434    79323P                   PINK CHERRY LIGHTS        12
# 2        489434    79323W                  WHITE CHERRY LIGHTS        12
# 3        489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4        489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
# ...         ...       ...                                  ...       ...
# 1007908  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 1007909  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 1007910  581587     22730           ALARM CLOCK BAKELIKE IVORY         4
# 1007911  581587     22367      CHILDRENS APRON SPACEBOY DESIGN         8
# 1007912  581587      POST                              POSTAGE         1
#
#                 InvoiceDate  Price  Customer ID         Country  Revenue  \
# ...

# %% [markdown]
# Sorting data by Date

# %%
df=df.sort_values(by='InvoiceDate')

# %%
print("Final Shape:", df.shape)

# Columns
print("\nColumns:\n", df.columns)

# Data Types
print("\nData Types:\n", df.dtypes)

# Missing Values
print("\nMissing Values:\n", df.isnull().sum())

# Duplicates
print("\nDuplicate Rows:", df.duplicated().sum())
# Out:
# Final Shape: (1007913, 13)
#
# Columns:
#  Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country', 'Revenue', 'Year', 'Month',
#        'DayofWeek', 'Hour'],
#       dtype='object')
#
# Data Types:
#  Invoice                object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# Price                 float64
# Customer ID           float64
# Country                object
# Revenue               float64
# Year                    int32
# Month                   int32
# DayofWeek              object
# Hour                    int32
# dtype: object
#
# Missing Values:
#  Invoice             0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    228488
# Country             0
# Revenue             0
# Year                0
# Month               0
# ...

# %%
print("Total Revenue:", df['Revenue'].sum())
print("Total Orders:", df['Invoice'].nunique())
print("Unique Customers:", df['Customer ID'].nunique())
# Out:
# Total Revenue: 20476260.447999995
# Total Orders: 40079
# Unique Customers: 5878

# %% [markdown]
# Revenue Trends

# %%
df.groupby('Month')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Month
# 11    2968159.922
# 10    2313165.950
# 12    2281745.010
# 9     1978132.183
# 3     1547130.521
# 6     1510084.320
# 8     1453093.290
# 5     1427002.110
# 7     1366886.391
# 1     1340966.722
# 4     1215843.743
# 2     1074050.286
# Name: Revenue, dtype: float64

# %% [markdown]
# Trend by Year

# %%
df.groupby('Year')['Revenue'].sum()
# Out:
# Year
# 2009     822483.950
# 2010    9833100.424
# 2011    9820676.074
# Name: Revenue, dtype: float64

# %% [markdown]
# Revenue by Day of the week

# %%
df.groupby('DayofWeek')['Revenue'].sum().sort_values(ascending=False)
# Out:
# DayofWeek
# Thursday     4195212.762
# Tuesday      4078149.962
# Monday       3581594.176
# Wednesday    3488444.333
# Friday       3323908.883
# Sunday       1799147.282
# Saturday        9803.050
# Name: Revenue, dtype: float64

# %% [markdown]
# ### Top Countries ###

# %%
df.groupby('Country')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Country
# United Kingdom          1.741020e+07
# EIRE                    6.587673e+05
# Netherlands             5.540381e+05
# Germany                 4.250197e+05
# France                  3.504561e+05
# Australia               1.692835e+05
# Spain                   1.083325e+05
# Switzerland             1.006856e+05
# Sweden                  9.186982e+04
# Denmark                 6.858069e+04
# Belgium                 6.538782e+04
# Norway                  5.632250e+04
# Portugal                5.628353e+04
# Channel Islands         4.462333e+04
# Japan                   4.302391e+04
# Italy                   3.210817e+04
# Finland                 2.992554e+04
# Singapore               2.531706e+04
# Cyprus                  2.484995e+04
# Hong Kong               2.368552e+04
# Austria                 2.361301e+04
# Greece                  1.909619e+04
# Israel                  1.132881e+04
# United Arab Emirates    1.109763e+04
# Unspecified             1.092716e+04
# ...

# %% [markdown]
# ### Top 10 Products ###

# %%
df.groupby('Description')['Revenue'].sum().sort_values(ascending =False).head(10)
# Out:
# Description
# Manual                                339241.29
# REGENCY CAKESTAND 3 TIER              330590.32
# DOTCOM POSTAGE                        309854.11
# WHITE HANGING HEART T-LIGHT HOLDER    260990.22
# PAPER CRAFT , LITTLE BIRDIE           168469.60
# PARTY BUNTING                         148318.28
# JUMBO BAG RED RETROSPOT               148073.47
# ASSORTED COLOUR BIRD ORNAMENT         129324.49
# POSTAGE                               125682.42
# PAPER CHAIN KIT 50'S CHRISTMAS        117760.29
# Name: Revenue, dtype: float64

# %% [markdown]
# ### Peak Hours ###

# %%
df.groupby('Hour')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Hour
# 12    2850377.671
# 10    2581131.333
# 13    2548467.544
# 11    2535325.463
# 15    2394943.792
# 14    2321684.731
# 9     1769631.031
# 16    1570143.801
# 17     861460.132
# 8      528185.570
# 18     273405.020
# 19     126830.350
# 7       75765.570
# 20      38904.190
# 6           4.250
# Name: Revenue, dtype: float64

# %% [markdown]
# ### Top 5 Hours with Highest Revenue ###

# %%
df.groupby('Hour')['Revenue'].sum().sort_values(ascending=False).head(5)
# Out:
# Hour
# 12    2850377.671
# 10    2581131.333
# 13    2548467.544
# 11    2535325.463
# 15    2394943.792
# Name: Revenue, dtype: float64

# %% [markdown]
# ## Data Visualization ##

# %% [markdown]
# ### Monthly Revenue Trend ###

# %%
import matplotlib.pyplot as plt

monthly_rev=df.groupby('Month')['Revenue'].sum()
monthly_rev.plot(figsize=(10,5))
plt.title('Monthly Revenue Trend')
plt.xlabel('Month No')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# ### Top 10 Products ###

# %%
import seaborn as sns
top_products=df.groupby('Description')['Revenue'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(10,5))
sns.barplot(x=top_products.values,y=top_products.index)
plt.title("Top 10 Products by Revenue")
plt.xlabel("Revenue")
plt.ylabel("Product")
plt.show()

# %% [markdown]
# ### Revenue by Country ###

# %%
top_country=df.groupby('Country')['Revenue'].sum().sort_values(ascending=False).head(5)
plt.figure(figsize=(10,5))
sns.barplot(x=top_country.index,y=top_country.values)
plt.title('Revenue by Country')
plt.xlabel('Country')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# ### Peak Hours ###

# %%
peak_hours=df.groupby('Hour')['Revenue'].sum()
plt.figure(figsize=(10,5))
sns.lineplot(x=peak_hours.index,y=peak_hours.values)
plt.title('Peak Hours by Revenue')
plt.xlabel('Hours')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# ### Day of Week vs Revenue ###

# %%
dow=df.groupby('DayofWeek')['Revenue'].sum().sort_values(ascending=False)
plt.figure(figsize=(10,5))
sns.barplot(x=dow.index,y=dow.values)
plt.title("Revenue by Day of Week")
plt.xlabel("Day")
plt.ylabel("Revenue")
plt.show()

# %%
df.to_csv(r"C:\Users\bhati\Downloads\archive (9)\online_retail_II.csv",index=False)

# %%
# !pip install pymysql

# %%
from sqlalchemy import create_engine

engine = create_engine(
    'mysql+pymysql://root:12345@localhost:3306/online_store'
)

df.to_sql(
    name='online_store',
    con=engine,
    if_exists='replace',
    index=False
)
# Out:
# 1007913
